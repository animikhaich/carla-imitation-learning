# %%
import torch
import torchvision
import fastseg
import numpy as np
from PIL import Image

# %%
seg_model = fastseg.MobileV3Large.from_pretrained().eval()
# Out:
# Loading pretrained model mobilev3large-lraspp with F=128...

# %%
image = "/projectnb/rlvn/animikh/carla-imitation-learning/data/validation_set/rgb/town_2_scc_1_28538.jpg"
image = np.array(Image.open(image))
preds = seg_model.predict(image)

# %%
preds.shape
# Out:
# (720, 1280)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
from fastseg.image import colorize

cimage = colorize(np.squeeze(preds))

# %%
np.array(cimage).shape
# Out:
# (720, 1280, 3)
